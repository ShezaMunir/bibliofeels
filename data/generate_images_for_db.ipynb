# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "drive/MyDrive/mlh-fellowship-hack"
# Out:
# /content/drive/MyDrive/mlh-fellowship-hack

# %%
import pandas as pd
df = pd.read_csv("database.csv", index_col=0)

# %%
df.head(5)
# Out:
#                          Wikipedia Link  ...                                           Emotions
# 0   https://en.wikipedia.org/?curid=620  ...              {'emotions': [{'sadness': 0.690489}]}
# 1   https://en.wikipedia.org/?curid=843  ...              {'emotions': [{'sadness': 0.570925}]}
# 2   https://en.wikipedia.org/?curid=986  ...              {'emotions': [{'sadness': 0.751417}]}
# 4  https://en.wikipedia.org/?curid=2080  ...  {'emotions': [{'sadness': 0.572753}, {'fear': ...
# 5  https://en.wikipedia.org/?curid=2152  ...              {'emotions': [{'sadness': 0.718911}]}
#
# [5 rows x 8 columns]

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader
search_list = []
def populate(term):
  if(term+ " book" not in not_needed):
    search_list.append(term+" book")
df['Book Title'].apply(lambda x: populate(x))
# Out:
# 0        None
# 1        None
# 2        None
# 4        None
# 5        None
#          ...
# 16549    None
# 16551    None
# 16555    None
# 16556    None
# 16558    None
# Name: Book Title, Length: 12841, dtype: object

# %%
len(search_list)
# Out:
# 639

# %%
import urllib.request

def download(term):
  downloader.download(term, limit=1,  output_dir='data1', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
for term in search_list:
  download(term)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/mlh-fellowship-hack/data1/Les Misérables book
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/91/54/5e/91545e042b65847725ea5b283c6a5ccf.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# ...
#
# Please show your support here
# https://www.buymeacoffee.com/gurugaurav
#
# ...
#
# [%] Downloading Images to /content/drive/My Drive/mlh-fellowship-hack/data1/Son Excellence Eugène Rougon book
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.ebayimg.com/images/g/5DUAAOSwjatbGWf2/s-l640.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# ...
#
# Please show your support here
# https://www.buymeacoffee.com/gurugaurav
#
# ...
#
# [%] Downloading Images to /content/drive/My Drive/mlh-fellowship-hack/data1/La Curée book
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ...
#
# ...

# %%
done = []
import os
done=os.listdir(r'data1/')

# %%
with open("dummy.jpg", "rb") as image2string:
      dummy = base64.b64encode(image2string.read())

import base64
b=[]
cs=[]
for dir in done:
  b.append(dir)
  try:
    with open("data1/"+dir+"/"+"Image_1.jpg", "rb") as image2string:
      cs.append(base64.b64encode(image2string.read()))
  except Exception as e:
    try:
      with open("data1/"+dir+"/"+"Image_1.png", "rb") as image2string:
        cs.append(base64.b64encode(image2string.read()))
    except Exception as e:
      cs.append(base64.b64encode(dummy))

# %%
bl = []
for i, book in enumerate(b):
  bl.append(b[i][:-5])

# %%
for i, book in enumerate(bl):
  df.at[df.index[df['Book Title'] == book],'Image URL']=cs[i]

# %%
decodeit = open('hello_level.jpeg', 'wb')
decodeit.write(base64.b64decode((cs[0])))
decodeit.close()

# %%
df.to_csv('final_database.csv')

# %%
df.to_json('final_database.json', orient = 'split', compression = 'infer')

# %%
dummy
# Out:
# b'...'
